# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\shree\Downloads\heart.csv")
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.shape
# Out:
# (918, 12)

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
#There are no null values present

# %%
df.skew()
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_19072\1665899112.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# Age            -0.195933
# RestingBP       0.179839
# Cholesterol    -0.610086
# FastingBS       1.264484
# MaxHR          -0.144359
# Oldpeak         1.022872
# HeartDisease   -0.215086
# dtype: float64

# %%
num = df.select_dtypes(include='number')

# %%
num
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
# [918 rows x 7 columns]

# %%
cat = df.select_dtypes(include='object')
cat
# Out:
#     Sex ChestPainType RestingECG ExerciseAngina ST_Slope
# 0     M           ATA     Normal              N       Up
# 1     F           NAP     Normal              N     Flat
# 2     M           ATA         ST              N       Up
# 3     F           ASY     Normal              Y     Flat
# 4     M           NAP     Normal              N       Up
# ..   ..           ...        ...            ...      ...
# 913   M            TA     Normal              N     Flat
# 914   M           ASY     Normal              N     Flat
# 915   M           ASY     Normal              Y     Flat
# 916   F           ATA        LVH              N     Flat
# 917   M           NAP     Normal              N       Up
#
# [918 rows x 5 columns]

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# <a id="uni"> </a>
# ## 1. Univariate Analysis

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_19072\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# The Age group 50 to 60 are higher than other age groups and the data is slightly left skewed
# but as considered between range it is normally distributed.

# %%
sns.distplot(df['RestingBP'])
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_19072\3603568707.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'])
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %% [markdown]
# Blood pressure ranging from 100 to 150 is higher in the list and looks like normal distribution.

# %%
sns.distplot(df['Cholesterol'])
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_19072\3250265040.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'])
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %% [markdown]
# #More number of persons have high cholestrol ranges from 200 to 300 and some of them have no cholestrol in the list
# #It is negatively skewed i.e Left skewed

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %%
sns.distplot(df['FastingBS'])
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_19072\2879572985.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['FastingBS'])
# <Axes: xlabel='FastingBS', ylabel='Density'>

# %% [markdown]
# It is right skewed where persons who were examined before fasting are high than after fasting.

# %%
sns.distplot(df['MaxHR'])
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_19072\3159621721.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MaxHR'])
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %% [markdown]
# It is normally distributed and maxHR ranges from 125 to 175 is high.

# %%
sns.distplot(df['Oldpeak'])
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_19072\283018971.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Oldpeak'])
# <Axes: xlabel='Oldpeak', ylabel='Density'>

# %% [markdown]
# It is strongly rightskewed.

# %%
sns.distplot(df['HeartDisease'])
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_19072\1967107602.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['HeartDisease'])
# <Axes: xlabel='HeartDisease', ylabel='Density'>

# %% [markdown]
# The data is normally distributed and persons with heart disease are high in count.

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Sex'>

# %% [markdown]
# There are 78.98% male and 21.02% female in the list.

# %%
cat
# Out:
#     Sex ChestPainType RestingECG ExerciseAngina ST_Slope
# 0     M           ATA     Normal              N       Up
# 1     F           NAP     Normal              N     Flat
# 2     M           ATA         ST              N       Up
# 3     F           ASY     Normal              Y     Flat
# 4     M           NAP     Normal              N       Up
# ..   ..           ...        ...            ...      ...
# 913   M            TA     Normal              N     Flat
# 914   M           ASY     Normal              N     Flat
# 915   M           ASY     Normal              Y     Flat
# 916   F           ATA        LVH              N     Flat
# 917   M           NAP     Normal              N       Up
#
# [918 rows x 5 columns]

# %%
df['ChestPainType'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ASY chestpain ranges high where as TA type ranges low.

# %%
df['RestingECG'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Most of the ECG are tends to be normal.

# %%
df['ExerciseAngina'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #There is no ExerciseAngina for most of the people people.

# %%
df['ST_Slope'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #The heart rate slope is flat for most of the people and the slope is down for minimum number of persons.

# %% [markdown]
# # Bivariate Analysis

# %%
sns.scatterplot(x=df['Age'],y=df['RestingBP'])
# Out:
# <Axes: xlabel='Age', ylabel='RestingBP'>

# %%
sns.scatterplot(x=df['Age'],y=df['Cholesterol'])
# Out:
# <Axes: xlabel='Age', ylabel='Cholesterol'>

# %%
sns.scatterplot(x=df['Age'],y=df['MaxHR'])
# Out:
# <Axes: xlabel='Age', ylabel='MaxHR'>

# %% [markdown]
# #It shows the negative relationship between age and maxHR

# %%
sns.scatterplot(x=df['Age'],y=df['Oldpeak'])
# Out:
# <Axes: xlabel='Age', ylabel='Oldpeak'>

# %% [markdown]
# #Relationship between age and old peak are moderate when compared to others.

# %% [markdown]
# # Multivariate Analysis

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_19072\621126171.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %% [markdown]
# #Comparing to other varibles in the dataset, The relationship between HeartDisease - Oldpeak and Heartdisease - Age are having a moderate
# #level of relationship with 0.4 and 0.28 respectively.
